# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
img1=cv2.imread('21.png')

# %%
plt.imshow(img1)

# %%
img2=cv2.imread('22.png')

# %%
plt.imshow(img2)

# %%
print(img1.shape)
print(img2.shape)
# Out:
# (1200, 1200, 3)
# (212, 238, 3)

# %%
img2_resized = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

# %%
add_img = cv2.add(img1, img2_resized)
plt.imshow(add_img)

# %%
weightedimg=cv2.addWeighted(img1,0.5,img2,0.4,0)
plt.imshow(weightedimg)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 weightedimg=cv2.addWeighted(img1,0.5,img2,0.4,0)
#       2 plt.imshow(weightedimg)
#
# error: OpenCV(4.11.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:665: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'

# %%
# Resize img2 to match img1
img2_resized = cv2.resize(img2, (img1.shape[1], img1.shape[0]))

# Now perform the weighted addition
weightedimg = cv2.addWeighted(img1, 0.5, img2_resized, 0.4, 0)

# Display result
plt.imshow(weightedimg)
plt.axis('off')
plt.show()

# %%
weightedimg = cv2.addWeighted(img1, 1, img2_resized, 1, 0)

# %%
plt.imshow(weightedimg)

# %%
weightedimg = cv2.addWeighted(img1, 0.2, img2_resized, 0.6, 0)
plt.imshow(weightedimg)

# %%
weightedimg = cv2.addWeighted(img1, 0.8, img2_resized, 0.5, 0)
plt.imshow(weightedimg)

# %%
weightedimg = cv2.addWeighted(img1, 0.5, img2_resized, 0.4, 10)
plt.imshow(weightedimg)

# %%
weightedimg = cv2.addWeighted(img1, 0.5, img2_resized, 0.4, 100)
plt.imshow(weightedimg)

# %%
weightedimg = cv2.addWeighted(img1, 0.5, img2_resized, 0.4, 200)
plt.imshow(weightedimg)

# %%
sub_img = cv2.subtract(img1, img2_resized)
plt.imshow(sub_img)

# %%
# Resize and match data type
img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))
img2 = img2.astype(img1.dtype)

# Bitwise AND operation
andimg = cv2.bitwise_and(img2, img1)

# Display result
plt.imshow(andimg)
plt.axis('off')
plt.show()

# %%
# Resize and match data type
img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))
img2 = img2.astype(img1.dtype)

# Bitwise AND operation
orimg = cv2.bitwise_or(img2, img1)

# Display result
plt.imshow(orimg
          )
plt.axis('off')
plt.show()

# %%
# Resize and match data type
img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))
img2 = img2.astype(img1.dtype)

# Bitwise AND operation
notimg = cv2.bitwise_not(img2, img1)

# Display result
plt.imshow(notimg)
plt.axis('off')
plt.show()

# %%
# Resize and match data type
img2 = cv2.resize(img2, (img1.shape[1], img1.shape[0]))
img2 = img2.astype(img1.dtype)

# Bitwise AND operation
xorimg = cv2.bitwise_xor(img2, img1)

# Display result
plt.imshow(xorimg)
plt.axis('off')
plt.show()
