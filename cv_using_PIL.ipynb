# %%
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image

# %%
img=Image.open('rgb.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=901x574>

# %%
img.getbbox()
# Out:
# (0, 0, 901, 574)

# %%
img.format
# Out:
# 'JPEG'

# %%
img.size
# Out:
# (901, 574)

# %%
img.resize((100,100))
# Out:
# <PIL.Image.Image image mode=RGB size=100x100>

# %%
img.rotate(90)
# Out:
# <PIL.Image.Image image mode=RGB size=901x574>

# %%
img.rotate(180)
# Out:
# <PIL.Image.Image image mode=RGB size=901x574>

# %%
img1=img.copy()

# %%
img.paste(img1,(400,600))

# %%
img.save('abc.jpg')

# %%
img.resize((500,100))
# Out:
# <PIL.Image.Image image mode=RGB size=500x100>

# %%
cropping=img.crop((0,0,500,500))

# %%
cropping
# Out:
# <PIL.Image.Image image mode=RGB size=500x500>

# %%
flip1=img.transpose(Image.FLIP_LEFT_RIGHT)
flip1
# Out:
# <PIL.Image.Image image mode=RGB size=901x574>

# %%
flip2=img.transpose(Image.FLIP_TOP_BOTTOM)
flip2
# Out:
# <PIL.Image.Image image mode=RGB size=901x574>

# %%
a=Image.open('cat.jpg')

# %%
a
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=183x276>

# %%
from PIL import Image,ImageFilter
b=a.filter(ImageFilter.BLUR)
b.show()

# %%
c=a.filter(ImageFilter.CONTOUR)
c.show()

# %%
D=a.filter(ImageFilter.EMBOSS)
D.show()

# %%
E=a.filter(ImageFilter.EDGE_ENHANCE)
E.show()

# %%
F=a.filter(ImageFilter.SMOOTH)
F.show()

# %%
imagesplit=Image.Image.split(img)
imagesplit[0].show()
imagesplit[1].show()
imagesplit[2].show()

# %%
arr=np.array(img)
plt.imshow(arr[:,:,0],cmap='grey')

# %%
plt.imshow(arr[:,:,1],cmap='grey')

# %%
plt.imshow(arr[:,:,2],cmap='grey')
